# %%
# %pip install cianparser
import cianparser

moscow_parser = cianparser.CianParser(location="Москва")
data = moscow_parser.get_flats(deal_type="sale", rooms=(5), with_saving_csv=True, with_extra_data=True, additional_settings={"start_page":1, "end_page":54})
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#
#                               Preparing to collect information from pages..
# The absolute path to the file:
# /home/user/Документы/Anchik/cian_flat_sale_1_54_moskva_24_Oct_2024_11_30_00_051577.csv
#
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room5=1
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room5=1
# The collection of information from the pages with ending parse on 1 page...
#
#
#
# Exception: 429 Client Error: Too Many Requests for url: https://www.cian.ru/cat.php?engine_version=2&p=2&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room5=1
# The collection of information from the pages with ending parse on 2 page...
#
#
#
# ...
